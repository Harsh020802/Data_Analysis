# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Questiond

# %% [markdown]
# ###Q1 Write a Python program to create and display a one-dimensional array-like object
# containing an array of data using Pandas module.

# %%
dict={
    "Name" : ['A','B','C','D'],
    "Age" : ['12','13','14','15'],
    "City" : ['Agra','Delhi','Haryana','Gurgao']
}
df=pd.DataFrame(dict)
df
# Out:
#   Name Age     City
# 0    A  12     Agra
# 1    B  13    Delhi
# 2    C  14  Haryana
# 3    D  15   Gurgao
